# %%
from bertopic import BERTopic
import pandas as pd
import numpy as np
from sklearn.utils import resample
import string
import contractions
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from matplotlib import pyplot as plt
import re
import seaborn as sns
from scipy.stats import pointbiserialr
import torch
torch.cuda.set_device(1)

# %%
df = pd.read_csv(f'/data/jmharja/projects/PersonaClassifier/twitter_SU/classification/2020_personality.csv')
trait_cols = ['cOPN', 'cCON', 'cEXT', 'cAGR', 'cNEU']
for col in trait_cols:
    mean_threshold = df[col].mean()
    df[f'{col}_class'] = np.where(df[col] >= mean_threshold, 1, 0)
    # print(df[f'{col}_class'].value_counts())

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
keywords_to_remove = {'user', 'hashtag', 'httpurl', 'url', 'http', 'https'}  
punctuation_table = str.maketrans('', '', string.punctuation)
def clean_text(text):
    text = text.lower().translate(punctuation_table)
    words = [
        word for word in text.split()
        if not word.isdigit() and len(word) >= 5
    ]
    words = [contractions.fix(word) for word in words]  # Optional: Only if needed
    words = [
        lemmatizer.lemmatize(word)
        for word in words
        if word not in stop_words and word not in keywords_to_remove
    ]
    return ' '.join(words)

# %%
# agr_df = pd.read_csv('alcohol_agr.csv')
agr_df = df[df['cAGR_class'] == 1]
agr_df = agr_df.drop_duplicates(subset=['text'])
agr_df['text'] = agr_df['text'].apply(clean_text)
agr_df = agr_df[agr_df['text'].apply(lambda x: len(x.split()) > 5)]
agr_df.shape
# Out:
# (249973, 27)

# %%
agr_texts = agr_df['text'].tolist()

# %%
# neu_df = pd.read_csv('alcohol/alcohol_neu.csv')
neu_df = df[df['cNEU_class'] == 1]
neu_df = neu_df.drop_duplicates(subset=['text'])
neu_df['text'] = neu_df['text'].apply(clean_text)
neu_df = neu_df[neu_df['text'].apply(lambda x: len(x.split()) > 5)]
print(neu_df.shape)
neu_texts = neu_df['text'].tolist()
# Out:
# (246155, 27)

# %%
# opn_df = pd.read_csv('alcohol/alcohol_opn.csv')
opn_df = df[df['cOPN_class'] == 1]
opn_df = opn_df.drop_duplicates(subset=['text'])
opn_df['text'] = opn_df['text'].apply(clean_text)
opn_df = opn_df[opn_df['text'].apply(lambda x: len(x.split()) > 5)]
print(opn_df.shape)
opn_texts = opn_df['text'].tolist()
# Out:
# (246697, 27)

# %%
# con_df = pd.read_csv('alcohol/alcohol_con.csv')
con_df = df[df['cCON_class'] == 1]
con_df = con_df.drop_duplicates(subset=['text'])
con_df['text'] = con_df['text'].apply(clean_text)
con_df = con_df[con_df['text'].apply(lambda x: len(x.split()) > 5)]
print(con_df.shape)
con_texts = con_df['text'].tolist()
# Out:
# (283930, 27)

# %%
# ext_df = pd.read_csv('alcohol/alcohol_ext.csv')
ext_df = df[df['cEXT_class'] == 1]
ext_df = ext_df.drop_duplicates(subset=['text'])
ext_df['text'] = ext_df['text'].apply(clean_text)
ext_df = ext_df[ext_df['text'].apply(lambda x: len(x.split()) > 5)]
print(ext_df.shape)
ext_texts = ext_df['text'].tolist()
# Out:
# (310245, 27)

# %%
from openai import OpenAI as OpenAIClient
from bertopic.representation import KeyBERTInspired, OpenAI, MaximalMarginalRelevance, PartOfSpeech
from sentence_transformers import SentenceTransformer
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")  
def get_model(trait):
    # KeyBERT:
    keybert_model = KeyBERTInspired()

    # Part-of-Speech
    # pos_model = PartOfSpeech("en_core_web_sm")

    # MMR
    mmr_model = MaximalMarginalRelevance(diversity=0.3)

    # GPT-3.5
    prompt = f"""
    I have a topic that contains the following documents:
    [DOCUMENTS]
    The topic is described by the following keywords: [KEYWORDS]

    Based on the information above, extract a short but highly descriptive topic label of at most 5 words that reflects traits of {trait}. Make sure it is in the following format:
    topic: <topic label>
    """

    client = OpenAIClient(api_key="")
    openai_model = OpenAI(client, model = "gpt-3.5-turbo", exponential_backoff=True, chat=True, prompt=prompt, delay_in_seconds=2,)

    representation_model = {
        "KeyBERT": keybert_model,
        "OpenAI": openai_model,  
        "MMR": mmr_model
        # "POS": pos_model
    }

    from bertopic import BERTopic
    from sentence_transformers import SentenceTransformer
    from umap import UMAP
    from hdbscan import HDBSCAN
    from sklearn.feature_extraction.text import CountVectorizer
    from nltk.corpus import stopwords

    stopwords = stopwords.words('english') + ['user', 'hashtag', 'httpurl', 'url', 'http', 'https']
    # embedding_model = SentenceTransformer("all-MiniLM-L6-v2", device="cuda")  # GPU

    umap_model = UMAP(n_neighbors=30, n_components=3, min_dist=0.1, metric="cosine")
    hdbscan_model = HDBSCAN(min_cluster_size=50, min_samples=20, metric="euclidean")
    # representation_model = KeyBERTInspired()

    model = BERTopic(
        nr_topics=10,
        umap_model=umap_model,
        hdbscan_model=hdbscan_model,
        embedding_model=embedding_model,
        vectorizer_model=CountVectorizer(stop_words=stopwords, ngram_range=(1, 2)),
        representation_model=representation_model,
        calculate_probabilities=False,    # Disable if not needed
        verbose=True
    )
    return model

# %%
neu_model = get_model("Neuroticism")
# agr_model = get_model("Aggreableness")
opn_model = get_model("Openness")
ext_model = get_model("Extraversion")
con_model = get_model("Conscientiousness")

# %%
# Precompute embeddings for speed
embeddings = embedding_model.encode(agr_texts, show_progress_bar=True)
# np.save('emb/agr_embeddings.npy', embeddings)
# Out:
# Batches:   0%|          | 0/7812 [00:00<?, ?it/s]

# %%
# embs = np.load('emb/agr_embeddings.npy')
topics, _ = agr_model.fit_transform(agr_texts, embeddings)
agr_topics = agr_model.get_topic_info()
agr_topics
# Out:
# 2025-06-03 17:54:17,667 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-06-03 17:58:15,029 - BERTopic - Dimensionality - Completed ✓
# 2025-06-03 17:58:15,034 - BERTopic - Cluster - Start clustering the reduced embeddings
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-06-03 17:58:23,453 - BERTopic - Cluster - Completed ✓
# 2025-06-03 17:58:23,454 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 100%|██████████| 383/383 [16:09<00:00,  2.53s/it]
# 2025-06-03 18:15:17,910 - BERTopic - Representation - Completed ✓
# 2025-06-03 18:15:17,971 - BERTopic - Topic reduction - Reducing number of topics
# 100%|██████████| 10/10 [00:24<00:00,  2.44s/it]
# 2025-06-03 18:15:55,620 - BERTopic - Topic reduction - Reduced number of topics from 383 to 10
#    Topic   Count                                      Name  \
# 0     -1  136175              -1_drink_smoke_alcohol_drunk
# 1      0   99238               0_drink_smoke_drunk_alcohol
# 2      1    6852                1_maine_trump_pelosi_biden
# 3      2    2894  2_upgrade_dolphin_arcade_dolphin dolphin
# 4      3    2278      3_gujarat_liquidation_please_company
# 5      4    1191         4_eligible_school_student_teacher
# 6      5     558    5_normalize_frequency_energy_vibration
# 7      6     442       6_aston_aston martin_martin_climate
# 8      7     292          7_penis_cramp_period_penis penis
# 9      8      53   8_ground ground_ground_ground holy_holy
#
#                                       Representation  \
# 0  [drink, smoke, alcohol, drunk, would, people, ...
# 1  [drink, smoke, drunk, alcohol, would, coffee, ...
# 2  [maine, trump, pelosi, biden, nobody, nobody n...
# 3  [upgrade, dolphin, arcade, dolphin dolphin, sa...
# 4  [gujarat, liquidation, please, company, reviva...
# 5  [eligible, school, student, teacher, undergrad...
# 6  [normalize, frequency, energy, vibration, norm...
# 7  [aston, aston martin, martin, climate, thunder...
# 8  [penis, cramp, period, penis penis, tooth, ank...
# 9  [ground ground, ground, ground holy, holy, lea...
#
#                                              KeyBERT  \
# 0  [drink, drinking, alcohol, drink water, drunk,...
# 1  [drink, drink coffee, drink alcohol, drinking,...
# 2  [nobody nobody, nobody, people, donald trump, ...
# 3  [upgrade, major upgrade, upgrade upgrade, mass...
# 4  [liquidation gujarat, gujarat liquidation, com...
# 5  [student eligible, eligible student, school el...
# 6  [normalize normalize, normalize, normalizing, ...
# 7  [aston martin, martin aston, aston, martin, po...
# 8  [penis penis, morning penis, penis, increase p...
# 9  [ground ground, ground, ground belongs, ground...
#
#                                     OpenAI  \
# 0              [Friendly Beverage Choices]
# 1                 [Social drinking habits]
# 2  [Nobody protests peacefully, agitated.]
# 3              [Friendly Dolphin Upgrades]
# 4       [Friendly Gujarat Company Revival]
# 5   [Eligible student grant opportunities]
# 6            [Harmonious Vibration Energy]
# 7              [Warm Aston Martin Weather]
# 8                     [Gentle Pain Relief]
# 9                  [Ground Harmony Traits]
#
#                                                  MMR  \
# 0  [drink, alcohol, drunk, would, water, drinking...
# 1  [drink, would, coffee, drinking, cocaine, covi...
# 2  [maine, pelosi, biden, nobody nobody, obama, b...
# 3  [upgrade, dolphin dolphin, luigis, luigi, tick...
# 4  [liquidation, liquidation contract, gujarat li...
# 5  [undergrad, stimulus, income, eligible voter, ...
# 6  [energy, vibrational, people normalize, normal...
# 7  [aston martin, climate, thunderstorm, sequeste...
# 8  [cramp, period, tooth, period cramp, increase ...
# 9  [ground ground, ground holy, leave ground, veg...
#
#                                  Representative_Docs
# 0  [anything heart condition drink energy drink, ...
# 1  [drink coffee remember sleep tonight anyway, r...
# 2  [nobody nobody nobody nobody nobody nobody nob...
# 3  [great upgrade though really upgrade would, de...
# 4  [please revival gujarat liquidation employee f...
# 5  [normally receive stimulus check still eligibl...
# 6  [normalize normalize normalize normalize norma...
# 7  [aston martin stock astoria aston martin deale...
# 8  [penis morning penis penis supper penis bagel ...
# 9  [ground ground ground ground ground ground, gr...

# %%
agr_topics.to_csv('emb/AGR_topic_10_modified_prompt.csv')

# %%
# Precompute embeddings for speed
neu_embeddings = embedding_model.encode(neu_texts, show_progress_bar=True)
topics, _ = neu_model.fit_transform(neu_texts, neu_embeddings)
neu_topics = neu_model.get_topic_info()
neu_topics.to_csv('emb/NEU_topic_10_modified_prompt.csv')
# Out:
# Batches:   0%|          | 0/7693 [00:00<?, ?it/s]
# 2025-06-03 18:25:53,344 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-06-03 18:29:06,925 - BERTopic - Dimensionality - Completed ✓
# 2025-06-03 18:29:06,932 - BERTopic - Cluster - Start clustering the reduced embeddings
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-06-03 18:29:14,038 - BERTopic - Cluster - Completed ✓
# 2025-06-03 18:29:14,039 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 100%|██████████| 340/340 [14:04<00:00,  2.48s/it]
# 2025-06-03 18:43:59,591 - BERTopic - Representation - Completed ✓
# 2025-06-03 18:43:59,651 - BERTopic - Topic reduction - Reducing number of topics
# 100%|██████████| 10/10 [00:27<00:00,  2.76s/it]
# 2025-06-03 18:44:38,838 - BERTopic - Topic reduction - Reduced number of topics from 340 to 10

# %%
# Precompute embeddings for speed
opn_embeddings = embedding_model.encode(opn_texts, show_progress_bar=True)
topics, _ = opn_model.fit_transform(opn_texts, opn_embeddings)
opn_topics = opn_model.get_topic_info()
opn_topics.to_csv('emb/OPN_topic_10_modified_prompt.csv')
opn_topics
# Out:
# Batches:   0%|          | 0/7710 [00:00<?, ?it/s]
# 2025-06-03 18:45:26,461 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-06-03 18:49:09,752 - BERTopic - Dimensionality - Completed ✓
# 2025-06-03 18:49:09,759 - BERTopic - Cluster - Start clustering the reduced embeddings
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-06-03 18:49:17,152 - BERTopic - Cluster - Completed ✓
# 2025-06-03 18:49:17,153 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 100%|██████████| 354/354 [14:46<00:00,  2.50s/it]
# 2025-06-03 19:04:48,488 - BERTopic - Representation - Completed ✓
# 2025-06-03 19:04:48,531 - BERTopic - Topic reduction - Reducing number of topics
# 100%|██████████| 10/10 [00:25<00:00,  2.58s/it]
# 2025-06-03 19:05:26,256 - BERTopic - Topic reduction - Reduced number of topics from 354 to 10
#    Topic   Count                                               Name  \
# 0     -1  134265                      -1_drink_alcohol_drunk_people
# 1      0   92386                         0_drink_smoke_drunk_people
# 2      1    8246                     1_protester_maine_trump_pelosi
# 3      2    3100                  2_eligible_homeless_school_health
# 4      3    2898                 3_upgrade_gujarat_cancel_downgrade
# 5      4    2626                    4_arcade_worcester_ticket_aston
# 6      5    1963    5_mercury_retrograde_mercury retrograde_freddie
# 7      6    1077  6_temperature_humidity hourly_hourly pressure_...
# 8      7      74  7_normalize_normalize normalize_normalize whit...
# 9      8      62  8_nobody nobody_nobody_somebody_nobody absolutely
#
#                                       Representation  \
# 0  [drink, alcohol, drunk, people, smoke, would, ...
# 1  [drink, smoke, drunk, people, alcohol, cigaret...
# 2  [protester, maine, trump, pelosi, voter, innoc...
# 3  [eligible, homeless, school, health, student, ...
# 4  [upgrade, gujarat, cancel, downgrade, liquidat...
# 5  [arcade, worcester, ticket, aston, luigis, gar...
# 6  [mercury, retrograde, mercury retrograde, fred...
# 7  [temperature, humidity hourly, hourly pressure...
# 8  [normalize, normalize normalize, normalize whi...
# 9  [nobody nobody, nobody, somebody, nobody absol...
#
#                                              KeyBERT  \
# 0  [drink, drink alcohol, drinking, alcohol, drun...
# 1  [drink, drinking, alcohol, tequila, drunk, cig...
# 2  [maine, susan collins, nancy pelosi, pelosi, s...
# 3  [eligible apply, eligibility, eligible, inelig...
# 4  [liquidation gujarat, gujarat liquidation, com...
# 5  [train worcester, worcester train, worcester, ...
# 6  [mercury retrograde, retrograde mercury, mercu...
# 7  [hourly pressure, humidity hourly, humidity, p...
# 8  [normalize normalize, normalize, normalize alo...
# 9  [nobody nobody, nobody nobodyyyyy, nobody some...
#
#                                     OpenAI  \
# 0        [Openness to Nightlife Enjoyment]
# 1                      [Openness to Vices]
# 2              [Maine Political Landscape]
# 3   [Eligibility for Discretionary Grants]
# 4      [Embracing Gujarat Revival Efforts]
# 5   [innovative train service improvement]
# 6         [Openness in Mercury Retrograde]
# 7           [Openness to Climate Patterns]
# 8  [Embracing Diverse Normalize Therapies]
# 9               [Embracing Openness Fully]
#
#                                                  MMR  \
# 0  [drink, alcohol, drunk, people, smoke, night, ...
# 1  [people, liquor, coffee, smoking, drinking, to...
# 2  [protester, maine, pelosi, innocence, biden, p...
# 3  [homeless, health, student, eligibility, incom...
# 4  [upgrade, cancel, company, liquidation contrac...
# 5  [worcester, aston, apple arcade, luigis mansio...
# 6  [mercury, mercury retrograde, freddie mercury,...
# 7  [humidity hourly, hourly pressure, humidity, g...
# 8  [normalize white, therapy normalize, serve nor...
# 9  [nobody nobody, twice nobody, dollar nobody, m...
#
#                                  Representative_Docs
# 0  [think alcohol inside covid really tolerance a...
# 1  [female friend wrong drunk drink friend drink ...
# 2  [susan collins maine january democratic senato...
# 3  [happen school parent eligible school have…, r...
# 4  [please liquidation gujarat employee family li...
# 5  [worcester train worcester auburndale minute b...
# 6  [little reminder astrogrammar mercury retrogra...
# 7  [temperature 111°c humidity hourly pressure sl...
# 8  [normalize normalize normalize normalize norma...
# 9  [nobody nobody nobody nobody nobody nobody, no...

# %%
# Precompute embeddings for speed
con_embeddings = embedding_model.encode(con_texts, show_progress_bar=True)
topics, _ = con_model.fit_transform(con_texts, con_embeddings)
con_topics = con_model.get_topic_info()
con_topics.to_csv('emb/CON_topic_10_modified_prompt.csv')
con_topics
# Out:
# Batches:   0%|          | 0/8873 [00:00<?, ?it/s]
# 2025-06-03 19:23:40,169 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-06-03 19:27:29,598 - BERTopic - Dimensionality - Completed ✓
# 2025-06-03 19:27:29,604 - BERTopic - Cluster - Start clustering the reduced embeddings
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-06-03 19:27:38,194 - BERTopic - Cluster - Completed ✓
# 2025-06-03 19:27:38,195 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 100%|██████████| 396/396 [16:17<00:00,  2.47s/it]
# 2025-06-03 19:44:48,158 - BERTopic - Representation - Completed ✓
# 2025-06-03 19:44:48,227 - BERTopic - Topic reduction - Reducing number of topics
# 100%|██████████| 10/10 [00:25<00:00,  2.52s/it]
# 2025-06-03 19:45:26,684 - BERTopic - Topic reduction - Reduced number of topics from 396 to 10
#    Topic   Count                                               Name  \
# 0     -1  149860                      -1_drink_drunk_people_alcohol
# 1      0  124349                         0_drink_smoke_drunk_people
# 2      1    3641                1_mercury_arcade_freddie_retrograde
# 3      2    1398                 2_homeless_library_eligible_school
# 4      3    1316  3_gujarat_liquidation_contract_liquidation con...
# 5      4    1103                  4_upgrade_downgrade_iphone_rating
# 6      5     969     5_pressure_temperature_blood pressure_humidity
# 7      6     850                6_maine_collins_susan_susan collins
# 8      7     353                 7_nobody_nobody nobody_bible_jesus
# 9      8      91  8_normalize_normalize normalize_dealer_people ...
#
#                                       Representation  \
# 0  [drink, drunk, people, alcohol, smoke, would, ...
# 1  [drink, smoke, drunk, people, cigarette, would...
# 2  [mercury, arcade, freddie, retrograde, freddie...
# 3  [homeless, library, eligible, school, teacher,...
# 4  [gujarat, liquidation, contract, liquidation c...
# 5  [upgrade, downgrade, iphone, rating, moody, wo...
# 6  [pressure, temperature, blood pressure, humidi...
# 7  [maine, collins, susan, susan collins, maine m...
# 8  [nobody, nobody nobody, bible, jesus, psalm, b...
# 9  [normalize, normalize normalize, dealer, peopl...
#
#                                              KeyBERT  \
# 0  [drink, drinking, alcohol, alcoholic, drunk, l...
# 1  [drink, alcohol, drinking, liquor, drunk, smok...
# 2  [freddie mercury, mercury mercury, retrograde ...
# 3  [people homeless, homeless people, homeless, h...
# 4  [greensquare bybit, contract greensquare, liqu...
# 5  [upgrade, upgraded, really upgrade, upgrade up...
# 6  [hourly pressure, humidity hourly, pressure te...
# 7  [maine susan, collins maine, senator maine, tr...
# 8  [nobody nobody, nobody, could nobody, nobody s...
# 9  [normalize normalize, normalize, normalize alo...
#
#                                      OpenAI  \
# 0             [Responsible Drinking Habits]
# 1  [Responsible alcohol consumption habits]
# 2      [Mercury Retrograde Frequency Study]
# 3               [Homeless Advocacy Efforts]
# 4         [Contract Liquidation Assessment]
# 5          [Consistent Technology Upgrades]
# 6          [Climate Change Impact Analysis]
# 7             [Maine Senator Susan Collins]
# 8     [Conscientious Worshipper Attributes]
# 9       [Organized and responsible mindset]
#
#                                                  MMR  \
# 0  [drink, drunk, alcohol, smoke, night, trump, l...
# 1  [drink, cigarette, would, think, covid19, trum...
# 2  [freddie mercury, mercury retrograde, luigis, ...
# 3  [homeless, eligible, teacher, public library, ...
# 4  [contract, liquidation contract, market, short...
# 5  [upgrade, downgrade, iphone, moody downgrade, ...
# 6  [blood pressure, hourly pressure, humidity hou...
# 7  [susan collins, collins maine, maine susan, ma...
# 8  [nobody nobody, psalm, worship, eligible etern...
# 9  [normalize, people normalize, public normalize...
#
#                                  Representative_Docs
# 0  [watch movie would drink instead dumbass…, nor...
# 1  [republican people drink drive arrest drunk dr...
# 2  [thread freddie mercury voice crown freddie me...
# 3  [homeless people maybe morning people sleep st...
# 4  [greensquare bybit btcusd short liquidation co...
# 5  [chrome thing maybe browser upgrade upgrade, u...
# 6  [temperature 183°c humidity hourly pressure sl...
# 7  [susan collins maine january democratic senato...
# 8  [nobody nobody nobody nobody nobody nobody nob...
# 9  [normalize normalize normalize normalize norma...

# %%
# Precompute embeddings for speed
ext_embeddings = embedding_model.encode(ext_texts, show_progress_bar=True)
topics, _ = ext_model.fit_transform(ext_texts, ext_embeddings)
ext_topics = ext_model.get_topic_info()
ext_topics.to_csv('emb/EXT_topic_10_modified_prompt.csv')
ext_topics
# Out:
# Batches:   0%|          | 0/9696 [00:00<?, ?it/s]
# 2025-06-03 19:46:25,285 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-06-03 19:51:08,924 - BERTopic - Dimensionality - Completed ✓
# 2025-06-03 19:51:08,929 - BERTopic - Cluster - Start clustering the reduced embeddings
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-06-03 19:51:18,323 - BERTopic - Cluster - Completed ✓
# 2025-06-03 19:51:18,324 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 100%|██████████| 393/393 [16:07<00:00,  2.46s/it]
# 2025-06-03 20:08:19,839 - BERTopic - Representation - Completed ✓
# 2025-06-03 20:08:19,911 - BERTopic - Topic reduction - Reducing number of topics
# 100%|██████████| 10/10 [00:26<00:00,  2.64s/it]
# 2025-06-03 20:09:01,067 - BERTopic - Topic reduction - Reduced number of topics from 393 to 10
#    Topic   Count                                               Name  \
# 0     -1  150361                      -1_drink_alcohol_drunk_people
# 1      0  140837                    0_smoke_drink_cigarette_alcohol
# 2      1   13560                   1_chinese_protester_trump_people
# 3      2    2571                 2_upgrade_downgrade_school_teacher
# 4      3    1143                3_gujarat_cancel_liquidation_please
# 5      4    1064            4_frequency_climate_energy_thunderstorm
# 6      5     303                  5_barber_shave_blade_arcane blade
# 7      6     232               6_violin_racquet_tennis_fruit violin
# 8      7     118  7_normalize_normalize normalize_people normali...
# 9      8      56        8_apple_apple apple_guess apple_apple thing
#
#                                       Representation  \
# 0  [drink, alcohol, drunk, people, would, think, ...
# 1  [smoke, drink, cigarette, alcohol, people, dru...
# 2  [chinese, protester, trump, people, maine, inn...
# 3  [upgrade, downgrade, school, teacher, student,...
# 4  [gujarat, cancel, liquidation, please, company...
# 5  [frequency, climate, energy, thunderstorm, gro...
# 6  [barber, shave, blade, arcane blade, beard, ar...
# 7  [violin, racquet, tennis, fruit violin, violin...
# 8  [normalize, normalize normalize, people normal...
# 9  [apple, apple apple, guess apple, apple thing,...
#
#                                              KeyBERT  \
# 0  [drink alcohol, drink, drinking, alcohol, alco...
# 1  [smoke cigarette, smoke, smoking, cigarette, t...
# 2  [white people, black people, racism, white, tr...
# 3  [grade downgrade, rating downgrade, moody down...
# 4  [liquidation gujarat, gujarat liquidation, com...
# 5  [frequency vibration, vibration frequency, vib...
# 6  [arcane blade, cornac arcane, hedgewizard trol...
# 7  [fruit violin, violin happy, violin piano, cha...
# 8  [normalize normalize, normalizing normalize, n...
# 9  [apple apple, kawhi apple, serious apple, appl...
#
#                                  OpenAI  \
# 0         [Social Drinking Personality]
# 1             [Social Smoking Behavior]
# 2          [Outspoken Political Events]
# 3         [Sociable School Environment]
# 4  [Sociable Gujarat Employees Revival]
# 5       [Vibrational Frequency Harmony]
# 6              [sociable blade wielder]
# 7       [Energetic socialite violinist]
# 8        [Normalize Social Interaction]
# 9           [Outgoing Apple Enthusiast]
#
#                                                  MMR  \
# 0  [drink, alcohol, drunk, bottle, liquor, drinki...
# 1  [would, coffee, smoking, cocaine, drinking, to...
# 2  [chinese, innocence, pelosi, voter, biden, oli...
# 3  [upgrade, downgrade, student, undergrad, grade...
# 4  [cancel culture, gujarat liquidation, revival ...
# 5  [climate, thunderstorm, ground ground, highvol...
# 6  [barber, shave, arcane blade, blade death, dea...
# 7  [fruit violin, violin happy, happy albert, cha...
# 8  [people normalize, public normalize, normalize...
# 9  [apple apple, guess apple, apple thing, kawhi ...
#
#                                  Representative_Docs
# 0  [suppose grown still people bottle drink think...
# 1  [remember progression smoke cigarette cigar sm...
# 2  [white people white people mitch right right p...
# 3  [moody downgrade india rating first patriot un...
# 4  [large manufacture company gujarat please revi...
# 5  [human meant vibrate frequency truth frequency...
# 6  [avaragard fourth1 cornac arcane blade death f...
# 7  [table chair fruit violin happy albert einstei...
# 8  [normalize normalize normalize normalize norma...
# 9  [kawhi apple though—so serious apple apple, ap...

# %%
agr_topics = pd.read_csv('emb/AGR_topic_10_modified_prompt.csv')
agr_topics[["Topic",   "OpenAI", "Representation", "Count"]].to_csv('emb/agr1.csv')

# %%
# agr_topics[["Topic",  "Count", "OpenAI", "Representation"]].to_csv('alcohol/agr.csv')
# neu_topics[["Topic",  "Count", "OpenAI", "Representation"]].to_csv('alcohol/neu.csv')
# opn_topics[["Topic",  "Count", "OpenAI", "Representation"]].to_csv('alcohol/opn.csv')
# con_topics[["Topic",  "Count", "OpenAI", "Representation"]].to_csv('alcohol/con.csv')
ext_topics[["Topic",  "Count", "OpenAI"]].to_csv('alcohol/ext.csv')

# ext_topics[["Topic",  "Count", "OpenAI", "Representation"]].to_csv('alcohol/ext.csv')
